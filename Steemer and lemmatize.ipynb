# %% [markdown]
# <a href="https://colab.research.google.com/github/musthak077/git_demo_remote/blob/master/Steemer%20and%20lemmatize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
article_text="Just what is agility in the context of software engineering work? Ivar Jacobs"

# %%
import re
import nltk
from nltk.tokenize import word_tokenize

# %%
article_text = article_text.lower()
article_text
# Out:
# 'just what is agility in the context of software engineering work? ivar jacobs'

# %%
clean_text = re.sub(r'[^a-zA-Z\s]', '', article_text)
clean_text
# Out:
# 'just what is agility in the context of software engineering work ivar jacobs'

# %%
sentence_list = nltk.sent_tokenize(article_text)
sentence_list
# Out:
# ['just what is agility in the context of software engineering work?',
#  'ivar jacobs']

# %%
tokens = word_tokenize(clean_text)
tokens
# Out:
# ['just',
#  'what',
#  'is',
#  'agility',
#  'in',
#  'the',
#  'context',
#  'of',
#  'software',
#  'engineering',
#  'work',
#  'ivar',
#  'jacobs']

# %%
nltk.download('stopwords')  # Download stopwords dataset
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
word_frequencies = {}
for word in tokens:
    if word not in stop_words:
        if word not in word_frequencies:
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1
word_frequencies
# Out:
# {'agility': 1,
#  'context': 1,
#  'software': 1,
#  'engineering': 1,
#  'work': 1,
#  'ivar': 1,
#  'jacobs': 1}

# %%
from collections import Counter
dictionary = Counter(word_frequencies)
dictionary
# Out:
# Counter({'agility': 1,
#          'context': 1,
#          'software': 1,
#          'engineering': 1,
#          'work': 1,
#          'ivar': 1,
#          'jacobs': 1})

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()

print(porter.stem("cats"))
print(lancaster.stem("cats"))
print(porter.stem("troubling"))
print(lancaster.stem("troubling"))
print(porter.stem("troubled"))
print(lancaster.stem("troubled"))
# Out:
# cat
# cat
# troubl
# troubl
# troubl
# troubl

# %%
word_list = ["friend", "friendship", "friends", "friendships", "stabil", "destabilize"]
print("{:20}{:20}{:20}".format("Word", "Porter Stemmer", "Lancaster Stemmer"))
for word in word_list:
    print("{:20}{:20}{:20}".format(word, porter.stem(word), lancaster.stem(word)))
# Out:
# Word                Porter Stemmer      Lancaster Stemmer
# friend              friend              friend
# friendship          friendship          friend
# friends             friend              friend
# friendships         friendship          friend
# stabil              stabil              stabl
# destabilize         destabil            dest

# %%
stem_sentence = []
for word in tokens:
    stem_sentence.append(porter.stem(word))
    stem_sentence.append(" ")
stem_sentence
# Out:
# ['just',
#  ' ',
#  'what',
#  ' ',
#  'is',
#  ' ',
#  'agil',
#  ' ',
#  'in',
#  ' ',
#  'the',
#  ' ',
#  'context',
#  ' ',
#  'of',
#  ' ',
#  'softwar',
#  ' ',
#  'engin',
#  ' ',
#  'work',
#  ' ',
#  'ivar',
#  ' ',
#  'jacob',
#  ' ']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_word(word):
    return lemmatizer.lemmatize(word)

# %%
word_list = ["word1", "word2", "word3"]
print("{:20}{:20}".format("Word", "Lemma"))
for word in word_list:
    print("{:20}{:20}".format(word, lemmatize_word(word)))
# Out:
# Word                Lemma
# word1               word1
# word2               word2
# word3               word3
