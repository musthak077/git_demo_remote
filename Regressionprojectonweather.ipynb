# %% [markdown]
# <a href="https://colab.research.google.com/github/musthak077/git_demo_remote/blob/master/Regressionprojectonweather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e6794c5e-038e-4091-ac6c-6aa497f0540b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6794c5e-038e-4091-ac6c-6aa497f0540b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as numpyInstace
import pandas as pandasInstance
import matplotlib.pyplot as matplotlibInstace
import seaborn as seabornInstance

# %%
weather = pandasInstance.read_csv('weather.csv')
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        14 non-null     float64
#  1   MaxTemp        14 non-null     float64
#  2   Rainfall       14 non-null     float64
#  3   Evaporation    14 non-null     float64
#  4   Sunshine       14 non-null     float64
#  5   WindGustDir    14 non-null     object
#  6   WindGustSpeed  14 non-null     int64
#  7   WindDir9am     14 non-null     object
#  8   WindDir3pm     14 non-null     object
#  9   WindSpeed9am   14 non-null     int64
#  10  WindSpeed3pm   14 non-null     int64
#  11  Humidity9am    14 non-null     int64
#  12  Humidity3pm    14 non-null     int64
#  13  Pressure9am    14 non-null     float64
#  14  Pressure3pm    14 non-null     float64
#  15  Cloud9am       14 non-null     int64
#  16  Cloud3pm       14 non-null     int64
# ...

# %%
weather.describe()
# Out:
#          MinTemp    MaxTemp   Rainfall  Evaporation   Sunshine  WindGustSpeed  \
# count  14.000000  14.000000  14.000000    14.000000  14.000000      14.000000
# mean    9.585714  22.278571   4.742857     5.442857   8.700000      43.571429
# std     2.659629   5.052978  10.973374     1.258029   3.232765      14.227353
# min     6.100000  15.500000   0.000000     3.400000   3.300000      30.000000
# 25%     8.075000  17.300000   0.000000     4.250000   6.650000      33.000000
# 50%     8.650000  23.100000   0.100000     5.600000   8.750000      42.000000
# 75%    11.600000  26.475000   3.400000     6.100000  11.575000      47.000000
# max    14.000000  30.900000  39.800000     7.200000  13.000000      85.000000
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# count     14.000000     14.000000    14.000000    14.000000    14.000000
# mean      11.642857     17.357143    69.071429    42.714286  1019.835714
# ...

# %%
seabornInstance.scatterplot(x='MinTemp', y='Humidity3pm', data=weather)
# Out:
# <Axes: xlabel='MinTemp', ylabel='Humidity3pm'>

# %%
seabornInstance.jointplot(x='MinTemp', y='Humidity3pm', data=weather,kind='hex')

# %%
seabornInstance.lmplot(x='MinTemp', y='Humidity3pm', data=weather)

# %%
X_features=weather[['Humidity3pm']]
X_features
# Out:
#     Humidity3pm
# 0            29
# 1            36
# 2            69
# 3            56
# 4            49
# 5            57
# 6            47
# 7            57
# 8            48
# 9            32
# 10           34
# 11           35
# 12           29
# 13           20

# %%
Y_Prediction=weather[['MinTemp']]
Y_Prediction
# Out:
#     MinTemp
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
# 5       6.2
# 6       6.1
# 7       8.3
# 8       8.8
# 9       8.4
# 10      9.1
# 11      8.5
# 12     10.1
# 13     12.1

# %%
print(coefficientInformation)
# Out:
# [[0.0217346]]

# %%
temperaturePredictions = linearRegression.predict(X_test)

# %%
temperaturePredictions
# Out:
# array([[10.30076   ],
#        [10.27902541],
#        [10.3224946 ]])

# %%
matplotlibInstace.scatter(y_test, temperaturePredictions)

# %%
seabornInstance.distplot(y_test-temperaturePredictions)
# Out:
# /tmp/ipython-input-3775198624.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seabornInstance.distplot(y_test-temperaturePredictions)
# <Axes: ylabel='Density'>

# %%
from sklearn import metrics

# %%
print(coefficientInformation)
# Out:
# [[0.0217346]]

# %%
metrics.mean_squared_error(y_test, temperaturePredictions)
# Out:
# 9.04283692767146

# %%
numpyInstace.sqrt(metrics.mean_squared_error(y_test, temperaturePredictions))
# Out:
# np.float64(3.0071310127215045)

# %%
print(coefficientInformation)
# Out:
# [[0.0217346]]
